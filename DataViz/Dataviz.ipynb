# %%
import pandas as pd
import os

# %% [markdown]
# ### Dataset Forbes miliardari 2023
# Diamo un'occhiata al dataset di Forbes dei miliardari nel 2023

# %% [markdown]
# Le colonne del dataset originale sono troppe...
#
#
# ['rank', 'finalWorth', 'category', 'personName', 'age', 'country',\
#        'city', 'source', 'industries', 'countryOfCitizenship', 'organization',\
#        'selfMade', 'status', 'gender', 'birthDate', 'lastName', 'firstName',\
#        'title', 'date', 'state', 'residenceStateRegion', 'birthYear',\
#        'birthMonth', 'birthDay', 'cpi_country', 'cpi_change_country',\
#        'gdp_country', 'gross_tertiary_education_enrollment',\
#        'gross_primary_education_enrollment_country', 'life_expectancy_country',\
#        'tax_revenue_country_country', 'total_tax_rate_country',\
#        'population_country', 'latitude_country', 'longitude_country']

# %%
file = pd.read_csv('Billionaires Dataset 2023.csv', usecols= ['rank', 'finalWorth', 'category', 'personName', 'age', 'country','city',
                                                                    'source', 'industries', 'countryOfCitizenship', 'organization','selfMade',
                                                                    'status', 'gender', 'birthDate','title',
                                                                    'tax_revenue_country_country', 'total_tax_rate_country'])
file
# Out:
#       rank  finalWorth               category                personName   age  \
# 0        1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1        2      180000             Automotive                 Elon Musk  51.0
# 2        3      114000             Technology                Jeff Bezos  59.0
# 3        4      107000             Technology             Larry Ellison  78.0
# 4        5      106000  Finance & Investments            Warren Buffett  92.0
# ...    ...         ...                    ...                       ...   ...
# 2635  2540        1000             Healthcare                   Yu Rong  51.0
# 2636  2540        1000        Food & Beverage    Richard Yuengling, Jr.  80.0
# 2637  2540        1000          Manufacturing             Zhang Gongyun  60.0
# 2638  2540        1000            Real Estate    Zhang Guiping & family  71.0
# 2639  2540        1000            Diversified               Inigo Zobel  66.0
#
# ...

# %%
file.isnull().sum()
# Out:
# rank                              0
# finalWorth                        0
# category                          0
# personName                        0
# age                              65
# country                          38
# city                             72
# source                            0
# industries                        0
# countryOfCitizenship              0
# organization                   2315
# selfMade                          0
# status                            0
# gender                            0
# birthDate                        76
# title                          2301
# tax_revenue_country_country     183
# total_tax_rate_country          182
# dtype: int64

# %%
file[['country', 'city']].isnull().sum()
# Out:
# country    38
# city       72
# dtype: int64

# %%
file.groupby('status').size()
# Out:
# status
# D                       1223
# E                        268
# N                        150
# R                         65
# Split Family Fortune      79
# U                        855
# dtype: int64

# %%
dataset = pd.read_csv('/Users/andreacardinali/Library/CloudStorage/OneDrive-UniversitàdegliStudidiMilano-Bicocca/Data Visualization/dataviz_github/dataviz/Billionaires_2001-2023.csv')

# %%
dataset.groupby('net_worth').size()

# %%
path = '/Users/andreacardinali/Library/CloudStorage/OneDrive-UniversitàdegliStudidiMilano-Bicocca/Data Visualization/dataviz_github/dataviz/archive'
for file_name in os.listdir(path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(path, file_name)
        dataset = pd.read_csv(file_path)
        dataset = dataset.head(20)
        dataset.to_csv(file_path, index=False)

# %%
dataframe = pd.DataFrame()
for file_name in os.listdir(path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(path, file_name)
        csv = pd.read_csv(file_path)
        dataframe = pd.concat([dataframe, csv])

# %%
dataframe['net_worth'] = dataframe['net_worth'].str.replace('B', '').astype(float)

# %%
dataframe.dtypes
# Out:
# year                          int64
# month                         int64
# rank                          int64
# net_worth                   float64
# last_name                    object
# first_name                   object
# full_name                    object
# birth_date                   object
# age                         float64
# gender                       object
# country_of_citizenship       object
# country_of_residence         object
# city_of_residence            object
# business_category            object
# business_industries          object
# organization_name            object
# position_in_organization     object
# self_made                    object
# wealth_status                object
# dtype: object

# %%
dataframe.to_csv('Billionaires_2001-2023.csv', index=False)
